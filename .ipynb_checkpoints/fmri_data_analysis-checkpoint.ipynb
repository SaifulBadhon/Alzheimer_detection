# %%
# !pip install dicom2nifti nibabel nilearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dicom2nifti
#   Downloading dicom2nifti-2.5.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting nibabel
#   Downloading nibabel-5.3.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting nilearn
#   Downloading nilearn-0.11.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from dicom2nifti) (1.26.4)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from dicom2nifti) (1.13.1)
# Collecting pydicom>=2.2.0 (from dicom2nifti)
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting python-gdcm (from dicom2nifti)
#   Downloading python_gdcm-3.0.24.1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: packaging>=20 in c:\programdata\anaconda3\lib\site-packages (from nibabel) (23.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\programdata\anaconda3\lib\site-packages (from nibabel) (4.11.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (1.4.2)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from nilearn) (5.2.1)
# Requirement already satisfied: pandas>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (2.32.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from nilearn) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.2.0->nilearn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.2.0->nilearn) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->nilearn) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->nilearn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->nilearn) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.0->nilearn) (2024.7.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->nilearn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.16.0)
# Downloading dicom2nifti-2.5.1-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#    ---------------------------------------- 43.6/43.6 kB 2.1 MB/s eta 0:00:00
# Downloading nibabel-5.3.2-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.3 MB 3.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/3.3 MB 2.7 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/3.3 MB 4.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.1/3.3 MB 6.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.0/3.3 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------- -- 3.1/3.3 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 11.6 MB/s eta 0:00:00
# Downloading nilearn-0.11.1-py3-none-any.whl (10.5 MB)
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.5 MB 26.4 MB/s eta 0:00:01
#    ------- -------------------------------- 1.9/10.5 MB 24.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.0/10.5 MB 24.2 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/10.5 MB 24.1 MB/s eta 0:00:01
#    -------------------- ------------------- 5.3/10.5 MB 24.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.5 MB 24.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.5 MB 22.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.5 MB 22.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.5/10.5 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.5 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.5/10.5 MB 23.4 MB/s eta 0:00:00
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.4 MB 26.1 MB/s eta 0:00:01
#    --------------------------------- ------ 2.0/2.4 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 25.2 MB/s eta 0:00:00
# Downloading python_gdcm-3.0.24.1-cp312-cp312-win_amd64.whl (28.9 MB)
#    ---------------------------------------- 0.0/28.9 MB ? eta -:--:--
#     --------------------------------------- 0.6/28.9 MB 18.5 MB/s eta 0:00:02
#    -- ------------------------------------- 1.8/28.9 MB 23.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.9/28.9 MB 23.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 4.3/28.9 MB 25.2 MB/s eta 0:00:01
#    ------- -------------------------------- 5.6/28.9 MB 25.8 MB/s eta 0:00:01
#    --------- ------------------------------ 7.2/28.9 MB 27.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 8.6/28.9 MB 27.5 MB/s eta 0:00:01
#    ------------- -------------------------- 9.6/28.9 MB 27.9 MB/s eta 0:00:01
#    -------------- ------------------------- 10.4/28.9 MB 26.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 11.7/28.9 MB 27.3 MB/s eta 0:00:01
#    ------------------ --------------------- 13.1/28.9 MB 28.5 MB/s eta 0:00:01
#    ------------------- -------------------- 13.9/28.9 MB 26.2 MB/s eta 0:00:01
#    -------------------- ------------------- 14.9/28.9 MB 25.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 16.2/28.9 MB 25.1 MB/s eta 0:00:01
#    ------------------------ --------------- 17.8/28.9 MB 25.2 MB/s eta 0:00:01
#    --------------------------- ------------ 19.5/28.9 MB 27.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 21.4/28.9 MB 31.2 MB/s eta 0:00:01
#    ------------------------------- -------- 23.0/28.9 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 25.1/28.9 MB 36.4 MB/s eta 0:00:01
#    ------------------------------------ --- 26.3/28.9 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------  28.6/28.9 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  28.9/28.9 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------- 28.9/28.9 MB 32.8 MB/s eta 0:00:00
# Installing collected packages: python-gdcm, pydicom, nibabel, dicom2nifti, nilearn
# Successfully installed dicom2nifti-2.5.1 nibabel-5.3.2 nilearn-0.11.1 pydicom-3.0.1 python-gdcm-3.0.24.1
#   WARNING: The scripts gdcmanon.exe, gdcmconv.exe, gdcmdiff.exe, gdcmdump.exe, gdcmgendir.exe, gdcmimg.exe, gdcminfo.exe, gdcmpap3.exe, gdcmraw.exe, gdcmscanner.exe, gdcmscu.exe, gdcmtar.exe and gdcmxml.exe are installed in 'C:\Users\SAIFUL_BADHON\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pydicom.exe is installed in 'C:\Users\SAIFUL_BADHON\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts nib-conform.exe, nib-convert.exe, nib-dicomfs.exe, nib-diff.exe, nib-ls.exe, nib-nifti-dx.exe, nib-roi.exe, nib-stats.exe, nib-tck2trk.exe, nib-trk2tck.exe and parrec2nii.exe are installed in 'C:\Users\SAIFUL_BADHON\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import pydicom
import numpy as np
import matplotlib.pyplot as plt

# Load a single DICOM file
dicom_path = r"C:\Users\SAIFUL_BADHON\Downloads\fMRI\ADNI\006_S_4546\Resting_State_fMRI\2012-09-24_12_27_31.0\I336551\ADNI_006_S_4546_MR_Resting_State_fMRI_br_raw_20120924163515733_2280_S168571_I336551.dcm"  # Change this to a real DICOM file path
dicom_data = pydicom.dcmread(dicom_path)

# Extract metadata
metadata_info = {
    "Patient ID": dicom_data.PatientID,
    "Patient Sex": dicom_data.PatientSex,
    "Modality": dicom_data.Modality,
    "Scan Date": dicom_data.StudyDate,
    "Institution": dicom_data.get("InstitutionName", "N/A"),
    "Repetition Time (TR)": dicom_data.get("RepetitionTime", "N/A"),
    "Echo Time (TE)": dicom_data.get("EchoTime", "N/A"),
}

# Print metadata
print("**DICOM Metadata:**")
for key, value in metadata_info.items():
    print(f"{key}: {value}")

# Extract and display the image
image_data = dicom_data.pixel_array
plt.figure(figsize=(6,6))
plt.imshow(image_data, cmap="gray")
plt.title("Single DICOM Slice")
plt.axis("off")
plt.show()
# Out:
# **DICOM Metadata:**
# Patient ID: 006_S_4546
# Patient Sex: M
# Modality: MR
# Scan Date: 20120924
# Institution: UNIVERSITY of MICHIGAN
# Repetition Time (TR): 3000
# Echo Time (TE): 30.001

# %%
import dicom2nifti
import nibabel as nib
from nilearn import plotting

# Define DICOM folder path
dicom_folder = r"C:\Users\SAIFUL_BADHON\Downloads\fMRI\ADNI\006_S_4546\Resting_State_fMRI\2012-09-24_12_27_31.0\I336551"  # Folder containing multiple DICOM files
nifti_output = r"C:\Users\SAIFUL_BADHON\Downloads\fMRI\output\abc.nii.gz"

# Convert DICOM folder to NIfTI
dicom2nifti.convert_directory(dicom_folder, os.path.dirname(nifti_output))
print(f"NIfTI file saved at {nifti_output}")
# Out:
# NIfTI file saved at C:\Users\SAIFUL_BADHON\Downloads\fMRI\output\abc.nii.gz

# %%
import nibabel as nib
import numpy as np
from nilearn import plotting

# Load the 4D fMRI NIfTI file
nifti_path = r"C:\Users\SAIFUL_BADHON\Downloads\fMRI\701_resting_state_fmri.nii.gz"
fmri_img = nib.load(nifti_path)

# Convert 4D to 3D: Take the mean across time
fmri_data = fmri_img.get_fdata()
mean_fmri_3d = np.mean(fmri_data, axis=-1)  # Averaging across time

# Save the 3D mean image as a new NIfTI file
mean_nifti = nib.Nifti1Image(mean_fmri_3d, affine=fmri_img.affine)
mean_nifti_path = "mean_fmri_3d.nii.gz"
nib.save(mean_nifti, mean_nifti_path)

# Now, plot the 3D NIfTI
plotting.plot_stat_map(mean_nifti_path, display_mode='z', cut_coords=10, title="Mean Brain Activation Map")
plotting.show()

# %%
# Now, plot the 3D NIfTI
plotting.plot_stat_map(mean_nifti_path, display_mode='x', cut_coords=10, title="Mean Brain Activation Map")
plotting.show()

# %%
# Now, plot the 3D NIfTI
plotting.plot_stat_map(mean_nifti_path, display_mode='y', cut_coords=10, title="Mean Brain Activation Map")
plotting.show()

# %%
# z → Axial view (top-down)

# x → Sagittal view (side view)

# y → Coronal view (front-to-back)

# %%
from nilearn import plotting

# Display slices along different axes
plotting.plot_stat_map(mean_nifti_path, display_mode='x', cut_coords=[-30, 0, 30], title="Sagittal (X-plane)")
plotting.plot_stat_map(mean_nifti_path, display_mode='y', cut_coords=[-50, 0, 50], title="Coronal (Y-plane)")
plotting.plot_stat_map(mean_nifti_path, display_mode='z', cut_coords=[-20, 0, 20], title="Axial (Z-plane)")

plotting.show()

# %%
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.
